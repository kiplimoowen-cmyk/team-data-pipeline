# %%
import pandas as pd
import numpy as np

# Sample data for Student A's step
data = {
    'Name': ['john', 'jane', 'jim', 'jack', 'jill'],
    'age': [20, 21, 22, 23, 24],
    'weight': [150, 155, 160, 165, 170],
}

df = pd.DataFrame(data)
df
# Out:
#    Name  age  weight
# 0  john   20     150
# 1  jane   21     155
# 2   jim   22     160
# 3  jack   23     165
# 4  jill   24     170

# %%
#Summary statistics for numeric columns
stats = df.describe()

# Calculate average (mean) values for age and weight
averages = df.mean(numeric_only=True)

# Calculate median values
median_age = df['age'].median()
median_weight = df['weight'].median()

# Calculate mode values
mode_age = df['age'].mode()[0]
mode_weight = df['weight'].mode()[0]

print("Descriptive Statistics:\n", stats)
print("\nAverage Values:\n", averages)
print("\nMedian Values:\n Age:", median_age, " Weight:", median_weight)
print("\nMode Values:\n Age:", mode_age, " Weight:", mode_weight)
# Out:
# Descriptive Statistics:
#               age      weight
# count   5.000000    5.000000
# mean   22.000000  160.000000
# std     1.581139    7.905694
# min    20.000000  150.000000
# 25%    21.000000  155.000000
# 50%    22.000000  160.000000
# 75%    23.000000  165.000000
# max    24.000000  170.000000
#
# Average Values:
#  age        22.0
# weight    160.0
# dtype: float64
#
# Median Values:
#  Age: 22.0  Weight: 160.0
#
# Mode Values:
#  Age: 20  Weight: 150

# %%
#Summary statistics for numeric columns
stats = df.describe()

# Calculate average (mean) values for age and weight
averages = df.mean(numeric_only=True)

# Calculate median values
median_age = df['age'].median()
median_weight = df['weight'].median()

# Calculate mode values
mode_age = df['age'].mode()[0]
mode_weight = df['weight'].mode()[0]

print("Descriptive Statistics:\n", stats)
print("\nAverage Values:\n", averages)
print("\nMedian Values:\n Age:", median_age, " Weight:", median_weight)
print("\nMode Values:\n Age:", mode_age, " Weight:", mode_weight)

# %% [markdown]
# This notebook cell demonstrates the creation and analysis of a simple dataset using **Pandas** and **NumPy**:
#
# - **Data Creation**: A DataFrame is built with sample student records (Name, Age, Weight).
# - **Summary Statistics**: `df.describe()` generates descriptive statistics (count, mean, std, min, quartiles, max).
# - **Averages**: Mean values for age and weight are calculated.
# - **Medians**: Median values for age and weight are computed.
# - **Modes**: Mode values (most frequent) for age and weight are identified.
